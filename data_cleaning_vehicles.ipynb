# %%
# %matplotlib inline
from IPython.display import display
import pandas as pd
import numpy as np

# %%
file_path = 'vehicles.csv'

autos = pd.read_csv(file_path)
# Out:
# /var/folders/f1/wtwxfqyx21l43chdpfznnk9h0000gn/T/ipykernel_2446/3701074153.py:3: DtypeWarning: Columns (70,71,72,73,74,76,79) have mixed types. Specify dtype option on import or set low_memory=False.
#   autos = pd.read_csv(file_path)

# %%
autos
# Out:
#        barrels08  barrelsA08  charge120  charge240  city08  city08U  cityA08  \
# 0      15.695714         0.0        0.0        0.0      19      0.0        0
# 1      29.964545         0.0        0.0        0.0       9      0.0        0
# 2      12.207778         0.0        0.0        0.0      23      0.0        0
# 3      29.964545         0.0        0.0        0.0      10      0.0        0
# 4      17.347895         0.0        0.0        0.0      17      0.0        0
# ...          ...         ...        ...        ...     ...      ...      ...
# 43658  14.982273         0.0        0.0        0.0      19      0.0        0
# 43659  14.330870         0.0        0.0        0.0      20      0.0        0
# 43660  15.695714         0.0        0.0        0.0      18      0.0        0
# 43661  15.695714         0.0        0.0        0.0      18      0.0        0
# 43662  18.311667         0.0        0.0        0.0      16      0.0        0
#
#        cityA08U  cityCD  cityE  ...  mfrCode  c240Dscr  charge240b  c240bDscr  \
# 0           0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 1           0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 2           0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 3           0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 4           0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# ...         ...     ...    ...  ...      ...       ...         ...        ...
# 43658       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 43659       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 43660       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 43661       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 43662       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
#
#                           createdOn                    modifiedOn  startStop  \
# 0      Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013        NaN
# 1      Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013        NaN
# 2      Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013        NaN
# 3      Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013        NaN
# 4      Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013        NaN
# ...                             ...                           ...        ...
# 43658  Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013        NaN
# 43659  Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013        NaN
# 43660  Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013        NaN
# 43661  Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013        NaN
# 43662  Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013        NaN
#
#        phevCity  phevHwy  phevComb
# 0             0        0         0
# 1             0        0         0
# 2             0        0         0
# 3             0        0         0
# 4             0        0         0
# ...         ...      ...       ...
# 43658         0        0         0
# 43659         0        0         0
# 43660         0        0         0
# 43661         0        0         0
# 43662         0        0         0
#
# [43663 rows x 83 columns]

# %%
autos.columns
# Out:
# Index(['barrels08', 'barrelsA08', 'charge120', 'charge240', 'city08',
#        'city08U', 'cityA08', 'cityA08U', 'cityCD', 'cityE', 'cityUF', 'co2',
#        'co2A', 'co2TailpipeAGpm', 'co2TailpipeGpm', 'comb08', 'comb08U',
#        'combA08', 'combA08U', 'combE', 'combinedCD', 'combinedUF', 'cylinders',
#        'displ', 'drive', 'engId', 'eng_dscr', 'feScore', 'fuelCost08',
#        'fuelCostA08', 'fuelType', 'fuelType1', 'ghgScore', 'ghgScoreA',
#        'highway08', 'highway08U', 'highwayA08', 'highwayA08U', 'highwayCD',
#        'highwayE', 'highwayUF', 'hlv', 'hpv', 'id', 'lv2', 'lv4', 'make',
#        'model', 'mpgData', 'phevBlended', 'pv2', 'pv4', 'range', 'rangeCity',
#        'rangeCityA', 'rangeHwy', 'rangeHwyA', 'trany', 'UCity', 'UCityA',
#        'UHighway', 'UHighwayA', 'VClass', 'year', 'youSaveSpend', 'guzzler',
#        'trans_dscr', 'tCharger', 'sCharger', 'atvType', 'fuelType2', 'rangeA',
#        'evMotor', 'mfrCode', 'c240Dscr', 'charge240b', 'c240bDscr',
#        'createdOn', 'modifiedOn', 'startStop', 'phevCity', 'phevHwy',
#        'phevComb'],
#       dtype='object')

# %%
cols = ['city08', 'comb08', 'highway08', 'cylinders', 'displ', 'drive', 'eng_dscr',
       'fuelCost08', 'make', 'model', 'trany', 'range', 'createdOn', 'year']

# %%
autos[cols].dtypes
# Out:
# city08          int64
# comb08          int64
# highway08       int64
# cylinders     float64
# displ         float64
# drive          object
# eng_dscr       object
# fuelCost08      int64
# make           object
# model          object
# trany          object
# range           int64
# createdOn      object
# year            int64
# dtype: object

# %%
autos[cols].memory_usage(deep = True)
# Out:
# Index             128
# city08         349304
# comb08         349304
# highway08      349304
# cylinders      349304
# displ          349304
# drive         3211492
# eng_dscr      2283917
# fuelCost08     349304
# make          2765868
# model         2988837
# trany         3116080
# range          349304
# createdOn     3711355
# year           349304
# dtype: int64

# %%
autos[cols].memory_usage(deep = True).sum()
# Out:
# 20872109

# %%
autos[cols].select_dtypes(int).describe()
# Out:
#              city08        comb08     highway08    fuelCost08         range  \
# count  43663.000000  43663.000000  43663.000000  43663.000000  43663.000000
# mean      18.693951     20.931475     24.802579   2554.683599      1.239333
# std        8.876232      8.508197      8.365106    714.729214     17.164369
# min        6.000000      7.000000      9.000000    450.000000      0.000000
# 25%       15.000000     17.000000     20.000000   2100.000000      0.000000
# 50%       17.000000     20.000000     24.000000   2550.000000      0.000000
# 75%       21.000000     23.000000     28.000000   2950.000000      0.000000
# max      150.000000    142.000000    133.000000   8000.000000    405.000000
#
#                year
# count  43663.000000
# mean    2002.643520
# std       11.706039
# min     1984.000000
# 25%     1992.000000
# 50%     2004.000000
# 75%     2013.000000
# max     2022.000000

# %%
# chaining

(autos
 [cols]
  .select_dtypes(int)
  .describe()
)
# Out:
#              city08        comb08     highway08    fuelCost08         range  \
# count  43663.000000  43663.000000  43663.000000  43663.000000  43663.000000
# mean      18.693951     20.931475     24.802579   2554.683599      1.239333
# std        8.876232      8.508197      8.365106    714.729214     17.164369
# min        6.000000      7.000000      9.000000    450.000000      0.000000
# 25%       15.000000     17.000000     20.000000   2100.000000      0.000000
# 50%       17.000000     20.000000     24.000000   2550.000000      0.000000
# 75%       21.000000     23.000000     28.000000   2950.000000      0.000000
# max      150.000000    142.000000    133.000000   8000.000000    405.000000
#
#                year
# count  43663.000000
# mean    2002.643520
# std       11.706039
# min     1984.000000
# 25%     1992.000000
# 50%     2004.000000
# 75%     2013.000000
# max     2022.000000

# %%
# can comb08 be an int8
np.iinfo(np.int8)
# Out:
# iinfo(min=-128, max=127, dtype=int8)

# %%
np.iinfo(np.int16)
# Out:
# iinfo(min=-32768, max=32767, dtype=int16)

# %%
(autos
 [cols]
  .astype({'highway08': 'int8', 'city08': 'int16', 'comb08': 'int16'})
  .select_dtypes([int, 'int8'])
  .describe()
)
# Out:
#           highway08    fuelCost08         range          year
# count  43663.000000  43663.000000  43663.000000  43663.000000
# mean      24.790853   2554.683599      1.239333   2002.643520
# std        8.393510    714.729214     17.164369     11.706039
# min     -124.000000    450.000000      0.000000   1984.000000
# 25%       20.000000   2100.000000      0.000000   1992.000000
# 50%       24.000000   2550.000000      0.000000   2004.000000
# 75%       28.000000   2950.000000      0.000000   2013.000000
# max      127.000000   8000.000000    405.000000   2022.000000

# %%
# chaining
# use 'integer' to see all int-like columns

(autos
 [cols]
  .astype({'highway08': 'int8', 'city08': 'int16', 'comb08': 'int16', 'fuelCost08': 'int16',
          'range': 'int16', 'year': 'int16'})
  .select_dtypes(['integer'])
  .describe()
)
# Out:
#              city08        comb08     highway08    fuelCost08         range  \
# count  43663.000000  43663.000000  43663.000000  43663.000000  43663.000000
# mean      18.693951     20.931475     24.790853   2554.683599      1.239333
# std        8.876232      8.508197      8.393510    714.729214     17.164369
# min        6.000000      7.000000   -124.000000    450.000000      0.000000
# 25%       15.000000     17.000000     20.000000   2100.000000      0.000000
# 50%       17.000000     20.000000     24.000000   2550.000000      0.000000
# 75%       21.000000     23.000000     28.000000   2950.000000      0.000000
# max      150.000000    142.000000    127.000000   8000.000000    405.000000
#
#                year
# count  43663.000000
# mean    2002.643520
# std       11.706039
# min     1984.000000
# 25%     1992.000000
# 50%     2004.000000
# 75%     2013.000000
# max     2022.000000

# %%
# chaining

(autos
 [cols]
  .astype({'highway08': 'int8', 'city08': 'int16', 'comb08': 'int16', 'fuelCost08': 'int16',
          'range': 'int16', 'year': 'int16'})
  .memory_usage(deep = True)
  .sum()
)
# Out:
# 19256578

# %%
# Float

(autos
 [cols]
 .select_dtypes('float'))
# Out:
#        cylinders  displ
# 0            4.0    2.0
# 1           12.0    4.9
# 2            4.0    2.2
# 3            8.0    5.2
# 4            4.0    2.2
# ...          ...    ...
# 43658        4.0    2.2
# 43659        4.0    2.2
# 43660        4.0    2.2
# 43661        4.0    2.2
# 43662        4.0    2.2
#
# [43663 rows x 2 columns]

# %%
# surprise! cylinders looks int-like
autos.cylinders.describe()
# Out:
# count    43373.000000
# mean         5.709312
# std          1.765310
# min          2.000000
# 25%          4.000000
# 50%          6.000000
# 75%          6.000000
# max         16.000000
# Name: cylinders, dtype: float64

# %%
autos.displ.describe()
# Out:
# count    43375.000000
# mean         3.283880
# std          1.357724
# min          0.000000
# 25%          2.200000
# 50%          3.000000
# 75%          4.300000
# max          8.400000
# Name: displ, dtype: float64

# %%
# opps! missing values
autos.cylinders.value_counts(dropna=False) # frequency of the entries
# Out:
# 4.0     17037
# 6.0     14978
# 8.0      9309
# 5.0       774
# 12.0      675
# 3.0       344
# NaN       290
# 10.0      179
# 2.0        63
# 16.0       14
# Name: cylinders, dtype: int64

# %%
# where are they missing?
(autos
 [cols]
 .query('cylinders.isna()')
)
# Out:
#        city08  comb08  highway08  cylinders  displ              drive  \
# 7138       81      85         91        NaN    NaN                NaN
# 7139       81      72         64        NaN    NaN      2-Wheel Drive
# 8143       81      72         64        NaN    NaN      2-Wheel Drive
# 8144       74      65         58        NaN    NaN                NaN
# 8146       45      39         33        NaN    NaN      2-Wheel Drive
# ...       ...     ...        ...        ...    ...                ...
# 37322     125     115        104        NaN    NaN  Front-Wheel Drive
# 37323     131     120        109        NaN    NaN  Front-Wheel Drive
# 37431     124     120        115        NaN    NaN    All-Wheel Drive
# 37432     107      99         91        NaN    NaN   Rear-Wheel Drive
# 37450     102     101         99        NaN    NaN    All-Wheel Drive
#
#       eng_dscr  fuelCost08        make                       model  \
# 7138       NaN         800      Nissan                    Altra EV
# 7139       NaN         900      Toyota                     RAV4 EV
# 8143       NaN         900      Toyota                     RAV4 EV
# 8144       NaN        1000        Ford                       Th!nk
# 8146       NaN        1700        Ford      Explorer USPS Electric
# ...        ...         ...         ...                         ...
# 37322      NaN         550   Chevrolet                    Bolt EUV
# 37323      NaN         550   Chevrolet                     Bolt EV
# 37431      NaN         550       Tesla          Model S Long Range
# 37432      NaN         650  Volkswagen                    ID.4 Pro
# 37450      NaN         650       Tesla  Model S Plaid (2in Wheels)
#
#                                   trany  range                     createdOn  \
# 7138                                NaN     90  Tue Jan 01 00:00:00 EST 2013
# 7139                                NaN     88  Tue Jan 01 00:00:00 EST 2013
# 8143                                NaN     88  Tue Jan 01 00:00:00 EST 2013
# 8144                                NaN     29  Tue Jan 01 00:00:00 EST 2013
# 8146                                NaN     38  Tue Jan 01 00:00:00 EST 2013
# ...                                 ...    ...                           ...
# 37322  Automatic (variable gear ratios)    247  Tue May 11 00:00:00 EDT 2021
# 37323  Automatic (variable gear ratios)    259  Tue May 11 00:00:00 EDT 2021
# 37431                    Automatic (A1)    405  Fri Jun 11 00:00:00 EDT 2021
# 37432                    Automatic (A1)    260  Fri Jun 11 00:00:00 EDT 2021
# 37450                    Automatic (A1)    348  Wed Jun 16 00:00:00 EDT 2021
#
#        year
# 7138   2000
# 7139   2000
# 8143   2001
# 8144   2001
# 8146   2001
# ...     ...
# 37322  2022
# 37323  2022
# 37431  2021
# 37432  2021
# 37450  2021
#
# [290 rows x 14 columns]

# %%
# chaining - add cylinders and displ columns

(autos
 [cols]
 .assign(cylinders=autos.cylinders.fillna(0).astype('int8'),
         displ=autos.displ.fillna(0))
 .astype({'highway08': 'int8', 'city08': 'int16', 'comb08': 'int16', 'fuelCost08': 'int16',
          'range': 'int16', 'year': 'int16'})
 .describe()
)
# Out:
#              city08        comb08     highway08     cylinders         displ  \
# count  43663.000000  43663.000000  43663.000000  43663.000000  43663.000000
# mean      18.693951     20.931475     24.790853      5.671392      3.262220
# std        8.876232      8.508197      8.393510      1.819529      1.379101
# min        6.000000      7.000000   -124.000000      0.000000      0.000000
# 25%       15.000000     17.000000     20.000000      4.000000      2.200000
# 50%       17.000000     20.000000     24.000000      6.000000      3.000000
# 75%       21.000000     23.000000     28.000000      6.000000      4.200000
# max      150.000000    142.000000    127.000000     16.000000      8.400000
#
#          fuelCost08         range          year
# count  43663.000000  43663.000000  43663.000000
# mean    2554.683599      1.239333   2002.643520
# std      714.729214     17.164369     11.706039
# min      450.000000      0.000000   1984.000000
# 25%     2100.000000      0.000000   1992.000000
# 50%     2550.000000      0.000000   2004.000000
# 75%     2950.000000      0.000000   2013.000000
# max     8000.000000    405.000000   2022.000000

# %%
autos[cols].describe()
# Out:
#              city08        comb08     highway08     cylinders         displ  \
# count  43663.000000  43663.000000  43663.000000  43373.000000  43375.000000
# mean      18.693951     20.931475     24.802579      5.709312      3.283880
# std        8.876232      8.508197      8.365106      1.765310      1.357724
# min        6.000000      7.000000      9.000000      2.000000      0.000000
# 25%       15.000000     17.000000     20.000000      4.000000      2.200000
# 50%       17.000000     20.000000     24.000000      6.000000      3.000000
# 75%       21.000000     23.000000     28.000000      6.000000      4.300000
# max      150.000000    142.000000    133.000000     16.000000      8.400000
#
#          fuelCost08         range          year
# count  43663.000000  43663.000000  43663.000000
# mean    2554.683599      1.239333   2002.643520
# std      714.729214     17.164369     11.706039
# min      450.000000      0.000000   1984.000000
# 25%     2100.000000      0.000000   1992.000000
# 50%     2550.000000      0.000000   2004.000000
# 75%     2950.000000      0.000000   2013.000000
# max     8000.000000    405.000000   2022.000000

# %%
# use this to inspect float sizes
np.finfo(np.float16)
# Out:
# finfo(resolution=0.001, min=-6.55040e+04, max=6.55040e+04, dtype=float16)

# %%
# chaining - convert displ to float16

(autos
 [cols]
 .assign(cylinders=autos.cylinders.fillna(0).astype('int8'),
         displ=autos.displ.fillna(0).astype('float16'))
 .astype({'highway08': 'int8', 'city08': 'int16', 'comb08': 'int16', 'fuelCost08': 'int16',
          'range': 'int16', 'year': 'int16'})
)
# Out:
#        city08  comb08  highway08  cylinders     displ  \
# 0          19      21         25          4  2.000000
# 1           9      11         14         12  4.898438
# 2          23      27         33          4  2.199219
# 3          10      11         12          8  5.199219
# 4          17      19         23          4  2.199219
# ...       ...     ...        ...        ...       ...
# 43658      19      22         26          4  2.199219
# 43659      20      23         28          4  2.199219
# 43660      18      21         24          4  2.199219
# 43661      18      21         24          4  2.199219
# 43662      16      18         21          4  2.199219
#
#                             drive    eng_dscr  fuelCost08        make  \
# 0                Rear-Wheel Drive       (FFS)        2200  Alfa Romeo
# 1                Rear-Wheel Drive   (GUZZLER)        4200     Ferrari
# 2               Front-Wheel Drive       (FFS)        1700       Dodge
# 3                Rear-Wheel Drive         NaN        4200       Dodge
# 4      4-Wheel or All-Wheel Drive  (FFS,TRBO)        2950      Subaru
# ...                           ...         ...         ...         ...
# 43658           Front-Wheel Drive       (FFS)        2100      Subaru
# 43659           Front-Wheel Drive       (FFS)        2000      Subaru
# 43660  4-Wheel or All-Wheel Drive       (FFS)        2200      Subaru
# 43661  4-Wheel or All-Wheel Drive       (FFS)        2200      Subaru
# 43662  4-Wheel or All-Wheel Drive  (FFS,TRBO)        3100      Subaru
#
#                      model            trany  range  \
# 0       Spider Veloce 2000     Manual 5-spd      0
# 1               Testarossa     Manual 5-spd      0
# 2                  Charger     Manual 5-spd      0
# 3      B150/B250 Wagon 2WD  Automatic 3-spd      0
# 4         Legacy AWD Turbo     Manual 5-spd      0
# ...                    ...              ...    ...
# 43658               Legacy  Automatic 4-spd      0
# 43659               Legacy     Manual 5-spd      0
# 43660           Legacy AWD  Automatic 4-spd      0
# 43661           Legacy AWD     Manual 5-spd      0
# 43662     Legacy AWD Turbo  Automatic 4-spd      0
#
#                           createdOn  year
# 0      Tue Jan 01 00:00:00 EST 2013  1985
# 1      Tue Jan 01 00:00:00 EST 2013  1985
# 2      Tue Jan 01 00:00:00 EST 2013  1985
# 3      Tue Jan 01 00:00:00 EST 2013  1985
# 4      Tue Jan 01 00:00:00 EST 2013  1993
# ...                             ...   ...
# 43658  Tue Jan 01 00:00:00 EST 2013  1993
# 43659  Tue Jan 01 00:00:00 EST 2013  1993
# 43660  Tue Jan 01 00:00:00 EST 2013  1993
# 43661  Tue Jan 01 00:00:00 EST 2013  1993
# 43662  Tue Jan 01 00:00:00 EST 2013  1993
#
# [43663 rows x 14 columns]

# %%
# new memory usage

(autos
 #[cols]
 .loc[:, cols]
 .assign(cylinders=autos.cylinders.fillna(0).astype('int8'),
         displ=autos.displ.fillna(0).astype('float16'))
 .astype({'highway08': 'int8', 'city08': 'int16', 'comb08': 'int16', 'fuelCost08': 'int16',
          'range': 'int16', 'year': 'int16'})
 .memory_usage(deep=True)
 .sum()
)
# Out:
# 18688959

# %%
# Objects

(autos
 [cols]
 .select_dtypes(object)
)
# Out:
#                             drive    eng_dscr        make  \
# 0                Rear-Wheel Drive       (FFS)  Alfa Romeo
# 1                Rear-Wheel Drive   (GUZZLER)     Ferrari
# 2               Front-Wheel Drive       (FFS)       Dodge
# 3                Rear-Wheel Drive         NaN       Dodge
# 4      4-Wheel or All-Wheel Drive  (FFS,TRBO)      Subaru
# ...                           ...         ...         ...
# 43658           Front-Wheel Drive       (FFS)      Subaru
# 43659           Front-Wheel Drive       (FFS)      Subaru
# 43660  4-Wheel or All-Wheel Drive       (FFS)      Subaru
# 43661  4-Wheel or All-Wheel Drive       (FFS)      Subaru
# 43662  4-Wheel or All-Wheel Drive  (FFS,TRBO)      Subaru
#
#                      model            trany                     createdOn
# 0       Spider Veloce 2000     Manual 5-spd  Tue Jan 01 00:00:00 EST 2013
# 1               Testarossa     Manual 5-spd  Tue Jan 01 00:00:00 EST 2013
# 2                  Charger     Manual 5-spd  Tue Jan 01 00:00:00 EST 2013
# 3      B150/B250 Wagon 2WD  Automatic 3-spd  Tue Jan 01 00:00:00 EST 2013
# 4         Legacy AWD Turbo     Manual 5-spd  Tue Jan 01 00:00:00 EST 2013
# ...                    ...              ...                           ...
# 43658               Legacy  Automatic 4-spd  Tue Jan 01 00:00:00 EST 2013
# 43659               Legacy     Manual 5-spd  Tue Jan 01 00:00:00 EST 2013
# 43660           Legacy AWD  Automatic 4-spd  Tue Jan 01 00:00:00 EST 2013
# 43661           Legacy AWD     Manual 5-spd  Tue Jan 01 00:00:00 EST 2013
# 43662     Legacy AWD Turbo  Automatic 4-spd  Tue Jan 01 00:00:00 EST 2013
#
# [43663 rows x 6 columns]

# %%
# looks categorical
(autos
 .drive.value_counts(dropna=False)
)
# Out:
# Front-Wheel Drive             14852
# Rear-Wheel Drive              14447
# 4-Wheel or All-Wheel Drive     6645
# All-Wheel Drive                3863
# 4-Wheel Drive                  1834
# NaN                            1186
# 2-Wheel Drive                   507
# Part-time 4-Wheel Drive         329
# Name: drive, dtype: int64

# %%
# where are the values missing for drive?
(autos
 [cols]
 .query('drive.isna()'))
# Out:
#        city08  comb08  highway08  cylinders  displ drive   eng_dscr  \
# 7138       81      85         91        NaN    NaN   NaN        NaN
# 8144       74      65         58        NaN    NaN   NaN        NaN
# 8147       84      75         66        NaN    NaN   NaN        NaN
# 18214      18      21         25        4.0    2.0   NaN      (FFS)
# 18215      20      22         26        4.0    1.5   NaN      (FFS)
# ...       ...     ...        ...        ...    ...   ...        ...
# 23019      79      85         94        NaN    NaN   NaN  Lead Acid
# 23020      35      37         39        NaN    NaN   NaN       NiMH
# 23022      49      48         46        NaN    NaN   NaN        NaN
# 23027      49      48         46        NaN    NaN   NaN        NaN
# 23030     102      98         94        NaN    NaN   NaN        NaN
#
#        fuelCost08        make               model           trany  range  \
# 7138          800      Nissan            Altra EV             NaN     90
# 8144         1000        Ford               Th!nk             NaN     29
# 8147          900      Nissan          Hyper-Mini             NaN     33
# 18214        2200  Alfa Romeo  Spider Veloce 2000    Manual 5-spd      0
# 18215        2100     Bertone                X1/9    Manual 5-spd      0
# ...           ...         ...                 ...             ...    ...
# 23019         800         GMC                 EV1  Automatic (A1)     55
# 23020        1750         GMC                 EV1  Automatic (A1)    105
# 23022        1400       Honda             EV Plus  Automatic (A1)     81
# 23027        1400       Honda             EV Plus  Automatic (A1)     81
# 23030         650        MINI               MiniE  Automatic (A1)    100
#
#                           createdOn  year
# 7138   Tue Jan 01 00:00:00 EST 2013  2000
# 8144   Tue Jan 01 00:00:00 EST 2013  2001
# 8147   Tue Jan 01 00:00:00 EST 2013  2001
# 18214  Tue Jan 01 00:00:00 EST 2013  1984
# 18215  Tue Jan 01 00:00:00 EST 2013  1984
# ...                             ...   ...
# 23019  Tue Jan 01 00:00:00 EST 2013  1999
# 23020  Tue Jan 01 00:00:00 EST 2013  1999
# 23022  Tue Jan 01 00:00:00 EST 2013  1999
# 23027  Tue Jan 01 00:00:00 EST 2013  1998
# 23030  Tue Jan 01 00:00:00 EST 2013  2008
#
# [1186 rows x 14 columns]

# %%
(autos
[cols]
.groupby('year')
.drive
.nunique())
# Out:
# year
# 1984    3
# 1985    4
# 1986    4
# 1987    3
# 1988    3
# 1989    3
# 1990    3
# 1991    3
# 1992    3
# 1993    3
# 1994    3
# 1995    4
# 1996    3
# 1997    4
# 1998    4
# 1999    4
# 2000    4
# 2001    4
# 2002    4
# 2003    4
# 2004    4
# 2005    4
# 2006    4
# 2007    4
# 2008    3
# 2009    4
# 2010    6
# 2011    5
# 2012    5
# 2013    5
# 2014    5
# 2015    5
# 2016    5
# 2017    5
# 2018    5
# 2019    5
# 2020    5
# 2021    5
# 2022    4
# Name: drive, dtype: int64

# %%
# drive and make (in.astype) to category

(autos
 [cols]
 .loc[:, cols]
 .assign(cylinders=autos.cylinders.fillna(0).astype('int8'),
         displ=autos.displ.fillna(0).astype('float16'),
         drive=autos.drive.fillna('other').astype('category')
        )
 .astype({'highway08': 'int8', 'city08': 'int16', 'comb08': 'int16', 'fuelCost08': 'int16',
          'range': 'int16', 'year': 'int16', 'make': 'category'})
 .memory_usage(deep=True)
 .sum()
)
# Out:
# 12857131

# %%
# let's inspect trany
# looks like it has two pieces of information embedded in column

(autos.trany.value_counts(dropna=False))
# Out:
# Automatic 4-spd                     11048
# Manual 5-spd                         8381
# Automatic (S6)                       3260
# Automatic 3-spd                      3151
# Manual 6-spd                         2903
# Automatic (S8)                       2279
# Automatic 5-spd                      2203
# Automatic 6-spd                      1733
# Manual 4-spd                         1483
# Automatic (variable gear ratios)      944
# Automatic (S5)                        839
# Automatic 7-spd                       720
# Automatic 8-spd                       633
# Automatic (AM-S7)                     566
# Automatic 9-spd                       516
# Automatic (S7)                        354
# Automatic (AM7)                       287
# Automatic (A1)                        284
# Automatic (S10)                       269
# Automatic (AV-S6)                     247
# Automatic (S4)                        233
# Automatic (AV-S7)                     178
# Automatic (AM6)                       160
# Automatic (S9)                        157
# Automatic (AM-S8)                     147
# Automatic (AM-S6)                     146
# Manual 7-spd                          130
# Automatic 10-spd                      122
# Automatic (AV-S8)                      98
# Manual 3-spd                           77
# Automatic (AV-S10)                     24
# Automatic (AM8)                        20
# Manual 4-spd Doubled                   17
# Automatic (AM5)                        14
# NaN                                    11
# Automatic (A2)                          9
# Automatic (AV-S1)                       9
# Automatic (AM-S9)                       5
# Automatic (L3)                          2
# Automatic (L4)                          2
# Automatic (AM-S10)                      2
# Name: trany, dtype: int64

# %%
# add automatic, speeds from trany, then drop trany

(autos
 [cols]
 .loc[:, cols]
 .assign(cylinders=autos.cylinders.fillna(0).astype('int8'),
         displ=autos.displ.fillna(0).astype('float16'),
         drive=autos.drive.fillna('other').astype('category'),
         automatic=autos.trany.str.contains('Auto'),
         speeds=autos.trany.str.extract(r'(\d)+').fillna('20').astype('int8')
        )
 .astype({'highway08': 'int8', 'city08': 'int16', 'comb08': 'int16', 'fuelCost08': 'int16',
          'range': 'int16', 'year': 'int16', 'make': 'category'})
 .drop(columns=['trany'])
 .memory_usage(deep=True)
 .sum()
)
# Out:
# 11304574

# %%
## Dates

# add createdOn
(autos
 [cols]
 .loc[:, cols]
 .assign(cylinders=autos.cylinders.fillna(0).astype('int8'),
         displ=autos.displ.fillna(0).astype('float16'),
         drive=autos.drive.fillna('other').astype('category'),
         automatic=autos.trany.str.contains('Auto'),
         speeds=autos.trany.str.extract(r'(\d)+').fillna('20').astype('int8'),
         createdOn=pd.to_datetime(autos.createdOn.replace({' EDT': '-04:00',
                                                          'EST': '-05:00'}, regex=True))
        )
 .astype({'highway08': 'int8', 'city08': 'int16', 'comb08': 'int16', 'fuelCost08': 'int16',
          'range': 'int16', 'year': 'int16', 'make': 'category'})
 .drop(columns=['trany'])
 .eng_dscr
 .value_counts(dropna=False)
)
# Out:
# NaN                             16563
# (FFS)                            8827
# SIDI                             6957
# (FFS) CA model                    926
# (FFS)      (MPFI)                 734
#                                 ...
# 200                                 1
# RNG=190                             1
# Shelby GT500; Coupe or Conv.        1
# RNG=250                             1
# MAZDA3 T/C                          1
# Name: eng_dscr, Length: 565, dtype: int64

# %%
# Python doesn't like EST/EDT
autos[cols].createdOn
# Out:
# 0        Tue Jan 01 00:00:00 EST 2013
# 1        Tue Jan 01 00:00:00 EST 2013
# 2        Tue Jan 01 00:00:00 EST 2013
# 3        Tue Jan 01 00:00:00 EST 2013
# 4        Tue Jan 01 00:00:00 EST 2013
#                      ...
# 43658    Tue Jan 01 00:00:00 EST 2013
# 43659    Tue Jan 01 00:00:00 EST 2013
# 43660    Tue Jan 01 00:00:00 EST 2013
# 43661    Tue Jan 01 00:00:00 EST 2013
# 43662    Tue Jan 01 00:00:00 EST 2013
# Name: createdOn, Length: 43663, dtype: object

# %%
# add ffs (Feedback fuel system), drop eng_dscr

(autos
 [cols]
 .loc[:, cols]
 .assign(cylinders=autos.cylinders.fillna(0).astype('int8'),
         displ=autos.displ.fillna(0).astype('float16'),
         drive=autos.drive.fillna('other').astype('category'),
         automatic=autos.trany.str.contains('Auto'),
         speeds=autos.trany.str.extract(r'(\d)+').fillna('20').astype('int8'),
         createdOn=pd.to_datetime(autos.createdOn.replace({' EDT': '-04:00',
                                                          'EST': '-05:00'}, regex=True)),
         ffs=autos.eng_dscr.str.contains('FFS')
        )
 .astype({'highway08': 'int8', 'city08': 'int16', 'comb08': 'int16', 'fuelCost08': 'int16',
          'range': 'int16', 'year': 'int16', 'make': 'category'})
 .drop(columns=['trany', 'eng_dscr'])
 .memory_usage(deep=True)
 .sum()
)
# Out:
# 9209074

# %%
# a glorious function

def tweak_autos(autos):
    cols = ['city08', 'comb08', 'highway08', 'cylinders', 'displ', 'drive', 'eng_dscr',
       'fuelCost08', 'make', 'model', 'trany', 'range', 'createdOn', 'year']
    return (autos
     [cols]
     .loc[:, cols]
     .assign(cylinders=autos.cylinders.fillna(0).astype('int8'),
             displ=autos.displ.fillna(0).astype('float16'),
             drive=autos.drive.fillna('other').astype('category'),
             automatic=autos.trany.str.contains('Auto'),
             speeds=autos.trany.str.extract(r'(\d)+').fillna('20').astype('int8'),
             createdOn=pd.to_datetime(autos.createdOn.replace({' EDT': '-04:00',
                                                              'EST': '-05:00'}, regex=True)),
             ffs=autos.eng_dscr.str.contains('FFS')
            )
     .astype({'highway08': 'int8', 'city08': 'int16', 'comb08': 'int16', 'fuelCost08': 'int16',
              'range': 'int16', 'year': 'int16', 'make': 'category'})
     .drop(columns=['trany', 'eng_dscr'])
    )
tweak_autos(autos)
# Out:
#        city08  comb08  highway08  cylinders     displ  \
# 0          19      21         25          4  2.000000
# 1           9      11         14         12  4.898438
# 2          23      27         33          4  2.199219
# 3          10      11         12          8  5.199219
# 4          17      19         23          4  2.199219
# ...       ...     ...        ...        ...       ...
# 43658      19      22         26          4  2.199219
# 43659      20      23         28          4  2.199219
# 43660      18      21         24          4  2.199219
# 43661      18      21         24          4  2.199219
# 43662      16      18         21          4  2.199219
#
#                             drive  fuelCost08        make  \
# 0                Rear-Wheel Drive        2200  Alfa Romeo
# 1                Rear-Wheel Drive        4200     Ferrari
# 2               Front-Wheel Drive        1700       Dodge
# 3                Rear-Wheel Drive        4200       Dodge
# 4      4-Wheel or All-Wheel Drive        2950      Subaru
# ...                           ...         ...         ...
# 43658           Front-Wheel Drive        2100      Subaru
# 43659           Front-Wheel Drive        2000      Subaru
# 43660  4-Wheel or All-Wheel Drive        2200      Subaru
# 43661  4-Wheel or All-Wheel Drive        2200      Subaru
# 43662  4-Wheel or All-Wheel Drive        3100      Subaru
#
#                      model  range                  createdOn  year automatic  \
# 0       Spider Veloce 2000      0  2013-01-01 00:00:00-05:00  1985     False
# 1               Testarossa      0  2013-01-01 00:00:00-05:00  1985     False
# 2                  Charger      0  2013-01-01 00:00:00-05:00  1985     False
# 3      B150/B250 Wagon 2WD      0  2013-01-01 00:00:00-05:00  1985      True
# 4         Legacy AWD Turbo      0  2013-01-01 00:00:00-05:00  1993     False
# ...                    ...    ...                        ...   ...       ...
# 43658               Legacy      0  2013-01-01 00:00:00-05:00  1993      True
# 43659               Legacy      0  2013-01-01 00:00:00-05:00  1993     False
# 43660           Legacy AWD      0  2013-01-01 00:00:00-05:00  1993      True
# 43661           Legacy AWD      0  2013-01-01 00:00:00-05:00  1993     False
# 43662     Legacy AWD Turbo      0  2013-01-01 00:00:00-05:00  1993      True
#
#        speeds    ffs
# 0           5   True
# 1           5  False
# 2           5   True
# 3           3    NaN
# 4           5   True
# ...       ...    ...
# 43658       4   True
# 43659       5   True
# 43660       4   True
# 43661       5   True
# 43662       4   True
#
# [43663 rows x 15 columns]

# %%
# Chain: is also called "flow" programming.Rather than making intermediate variables , 
# just leverage the fact that mosst operations return a new objects and work on that. 
# The chai should read like a reciepe of ordered steps. 


def tweak_autos(autos):
    cols = ['city08', 'comb08', 'highway08', 'cylinders', 'displ', 'drive', 'eng_dscr',
       'fuelCost08', 'make', 'model', 'trany', 'range', 'createdOn', 'year']
    return (autos
     [cols]
     .loc[:, cols]
     .assign(cylinders=autos.cylinders.fillna(0).astype('int8'),
             displ=autos.displ.fillna(0).astype('float16'),
             drive=autos.drive.fillna('other').astype('category'),
             automatic=autos.trany.str.contains('Auto'),
             speeds=autos.trany.str.extract(r'(\d)+').fillna('20').astype('int8'),
             createdOn=pd.to_datetime(autos.createdOn.replace({' EDT': '-04:00',
                                                              'EST': '-05:00'}, regex=True)),
             ffs=autos.eng_dscr.str.contains('FFS')
            )
     .astype({'highway08': 'int8', 'city08': 'int16', 'comb08': 'int16', 'fuelCost08': 'int16',
              'range': 'int16', 'year': 'int16', 'make': 'category'})
     .drop(columns=['trany', 'eng_dscr'])
    )
tweak_autos(autos)
# Out:
#        city08  comb08  highway08  cylinders     displ  \
# 0          19      21         25          4  2.000000
# 1           9      11         14         12  4.898438
# 2          23      27         33          4  2.199219
# 3          10      11         12          8  5.199219
# 4          17      19         23          4  2.199219
# ...       ...     ...        ...        ...       ...
# 43658      19      22         26          4  2.199219
# 43659      20      23         28          4  2.199219
# 43660      18      21         24          4  2.199219
# 43661      18      21         24          4  2.199219
# 43662      16      18         21          4  2.199219
#
#                             drive  fuelCost08        make  \
# 0                Rear-Wheel Drive        2200  Alfa Romeo
# 1                Rear-Wheel Drive        4200     Ferrari
# 2               Front-Wheel Drive        1700       Dodge
# 3                Rear-Wheel Drive        4200       Dodge
# 4      4-Wheel or All-Wheel Drive        2950      Subaru
# ...                           ...         ...         ...
# 43658           Front-Wheel Drive        2100      Subaru
# 43659           Front-Wheel Drive        2000      Subaru
# 43660  4-Wheel or All-Wheel Drive        2200      Subaru
# 43661  4-Wheel or All-Wheel Drive        2200      Subaru
# 43662  4-Wheel or All-Wheel Drive        3100      Subaru
#
#                      model  range                  createdOn  year automatic  \
# 0       Spider Veloce 2000      0  2013-01-01 00:00:00-05:00  1985     False
# 1               Testarossa      0  2013-01-01 00:00:00-05:00  1985     False
# 2                  Charger      0  2013-01-01 00:00:00-05:00  1985     False
# 3      B150/B250 Wagon 2WD      0  2013-01-01 00:00:00-05:00  1985      True
# 4         Legacy AWD Turbo      0  2013-01-01 00:00:00-05:00  1993     False
# ...                    ...    ...                        ...   ...       ...
# 43658               Legacy      0  2013-01-01 00:00:00-05:00  1993      True
# 43659               Legacy      0  2013-01-01 00:00:00-05:00  1993     False
# 43660           Legacy AWD      0  2013-01-01 00:00:00-05:00  1993      True
# 43661           Legacy AWD      0  2013-01-01 00:00:00-05:00  1993     False
# 43662     Legacy AWD Turbo      0  2013-01-01 00:00:00-05:00  1993      True
#
#        speeds    ffs
# 0           5   True
# 1           5  False
# 2           5   True
# 3           3    NaN
# 4           5   True
# ...       ...    ...
# 43658       4   True
# 43659       5   True
# 43660       4   True
# 43661       5   True
# 43662       4   True
#
# [43663 rows x 15 columns]

# %%
# easy to debug
# - assign to var (df3)
# - comment out
# - pipe to display


from IPython.display import display

def get_var(df, var_name):
    globals()[var_name] = df
    return df

def tweak_autos(autos):
    return (autos
     [cols]
     # create var
     .pipe(get_var, 'df3')
     .assign(cylinders=autos.cylinders.fillna(0).astype('int8'),
             displ=autos.displ.fillna(0).astype('float16'),
             drive=autos.drive.fillna('other').astype('category'),
             automatic=autos.trany.str.contains('Auto'),
             speeds=autos.trany.str.extract(r'(\d)+').fillna('20').astype('int8'),
             createdOn=pd.to_datetime(autos.createdOn.replace({' EDT': '-04:00',
                                                              'EST': '-05:00'}, regex=True)),
             ffs=autos.eng_dscr.str.contains('FFS')
            )
     # debug pipe
     .pipe(lambda df: display(df) or df)
     .astype({'highway08': 'int8', 'city08': 'int16', 'comb08': 'int16', 'fuelCost08': 'int16',
              'range': 'int16', 'year': 'int16', 'make': 'category'})
     .drop(columns=['trany', 'eng_dscr'])
    )
tweak_autos(autos)
# Out:
#        city08  comb08  highway08  cylinders     displ  \
# 0          19      21         25          4  2.000000
# 1           9      11         14         12  4.898438
# 2          23      27         33          4  2.199219
# 3          10      11         12          8  5.199219
# 4          17      19         23          4  2.199219
# ...       ...     ...        ...        ...       ...
# 43658      19      22         26          4  2.199219
# 43659      20      23         28          4  2.199219
# 43660      18      21         24          4  2.199219
# 43661      18      21         24          4  2.199219
# 43662      16      18         21          4  2.199219
#
#                             drive    eng_dscr  fuelCost08        make  \
# 0                Rear-Wheel Drive       (FFS)        2200  Alfa Romeo
# 1                Rear-Wheel Drive   (GUZZLER)        4200     Ferrari
# 2               Front-Wheel Drive       (FFS)        1700       Dodge
# 3                Rear-Wheel Drive         NaN        4200       Dodge
# 4      4-Wheel or All-Wheel Drive  (FFS,TRBO)        2950      Subaru
# ...                           ...         ...         ...         ...
# 43658           Front-Wheel Drive       (FFS)        2100      Subaru
# 43659           Front-Wheel Drive       (FFS)        2000      Subaru
# 43660  4-Wheel or All-Wheel Drive       (FFS)        2200      Subaru
# 43661  4-Wheel or All-Wheel Drive       (FFS)        2200      Subaru
# 43662  4-Wheel or All-Wheel Drive  (FFS,TRBO)        3100      Subaru
#
#                      model            trany  range                  createdOn  \
# 0       Spider Veloce 2000     Manual 5-spd      0  2013-01-01 00:00:00-05:00
# 1               Testarossa     Manual 5-spd      0  2013-01-01 00:00:00-05:00
# 2                  Charger     Manual 5-spd      0  2013-01-01 00:00:00-05:00
# 3      B150/B250 Wagon 2WD  Automatic 3-spd      0  2013-01-01 00:00:00-05:00
# 4         Legacy AWD Turbo     Manual 5-spd      0  2013-01-01 00:00:00-05:00
# ...                    ...              ...    ...                        ...
# 43658               Legacy  Automatic 4-spd      0  2013-01-01 00:00:00-05:00
# 43659               Legacy     Manual 5-spd      0  2013-01-01 00:00:00-05:00
# 43660           Legacy AWD  Automatic 4-spd      0  2013-01-01 00:00:00-05:00
# 43661           Legacy AWD     Manual 5-spd      0  2013-01-01 00:00:00-05:00
# 43662     Legacy AWD Turbo  Automatic 4-spd      0  2013-01-01 00:00:00-05:00
#
#        year automatic  speeds    ffs
# 0      1985     False       5   True
# 1      1985     False       5  False
# 2      1985     False       5   True
# 3      1985      True       3    NaN
# 4      1993     False       5   True
# ...     ...       ...     ...    ...
# 43658  1993      True       4   True
# 43659  1993     False       5   True
# 43660  1993      True       4   True
# 43661  1993     False       5   True
# 43662  1993      True       4   True
#
# [43663 rows x 17 columns]
#        city08  comb08  highway08  cylinders     displ  \
# 0          19      21         25          4  2.000000
# 1           9      11         14         12  4.898438
# 2          23      27         33          4  2.199219
# 3          10      11         12          8  5.199219
# 4          17      19         23          4  2.199219
# ...       ...     ...        ...        ...       ...
# 43658      19      22         26          4  2.199219
# 43659      20      23         28          4  2.199219
# 43660      18      21         24          4  2.199219
# 43661      18      21         24          4  2.199219
# 43662      16      18         21          4  2.199219
#
#                             drive  fuelCost08        make  \
# 0                Rear-Wheel Drive        2200  Alfa Romeo
# 1                Rear-Wheel Drive        4200     Ferrari
# 2               Front-Wheel Drive        1700       Dodge
# 3                Rear-Wheel Drive        4200       Dodge
# 4      4-Wheel or All-Wheel Drive        2950      Subaru
# ...                           ...         ...         ...
# 43658           Front-Wheel Drive        2100      Subaru
# 43659           Front-Wheel Drive        2000      Subaru
# 43660  4-Wheel or All-Wheel Drive        2200      Subaru
# 43661  4-Wheel or All-Wheel Drive        2200      Subaru
# 43662  4-Wheel or All-Wheel Drive        3100      Subaru
#
#                      model  range                  createdOn  year automatic  \
# 0       Spider Veloce 2000      0  2013-01-01 00:00:00-05:00  1985     False
# 1               Testarossa      0  2013-01-01 00:00:00-05:00  1985     False
# 2                  Charger      0  2013-01-01 00:00:00-05:00  1985     False
# 3      B150/B250 Wagon 2WD      0  2013-01-01 00:00:00-05:00  1985      True
# 4         Legacy AWD Turbo      0  2013-01-01 00:00:00-05:00  1993     False
# ...                    ...    ...                        ...   ...       ...
# 43658               Legacy      0  2013-01-01 00:00:00-05:00  1993      True
# 43659               Legacy      0  2013-01-01 00:00:00-05:00  1993     False
# 43660           Legacy AWD      0  2013-01-01 00:00:00-05:00  1993      True
# 43661           Legacy AWD      0  2013-01-01 00:00:00-05:00  1993     False
# 43662     Legacy AWD Turbo      0  2013-01-01 00:00:00-05:00  1993      True
#
#        speeds    ffs
# 0           5   True
# 1           5  False
# 2           5   True
# 3           3    NaN
# 4           5   True
# ...       ...    ...
# 43658       4   True
# 43659       5   True
# 43660       4   True
# 43661       5   True
# 43662       4   True
#
# [43663 rows x 15 columns]

# %%
# inspect intermediate data frame
df3
# Out:
#        city08  comb08  highway08  cylinders  displ  \
# 0          19      21         25        4.0    2.0
# 1           9      11         14       12.0    4.9
# 2          23      27         33        4.0    2.2
# 3          10      11         12        8.0    5.2
# 4          17      19         23        4.0    2.2
# ...       ...     ...        ...        ...    ...
# 43658      19      22         26        4.0    2.2
# 43659      20      23         28        4.0    2.2
# 43660      18      21         24        4.0    2.2
# 43661      18      21         24        4.0    2.2
# 43662      16      18         21        4.0    2.2
#
#                             drive    eng_dscr  fuelCost08        make  \
# 0                Rear-Wheel Drive       (FFS)        2200  Alfa Romeo
# 1                Rear-Wheel Drive   (GUZZLER)        4200     Ferrari
# 2               Front-Wheel Drive       (FFS)        1700       Dodge
# 3                Rear-Wheel Drive         NaN        4200       Dodge
# 4      4-Wheel or All-Wheel Drive  (FFS,TRBO)        2950      Subaru
# ...                           ...         ...         ...         ...
# 43658           Front-Wheel Drive       (FFS)        2100      Subaru
# 43659           Front-Wheel Drive       (FFS)        2000      Subaru
# 43660  4-Wheel or All-Wheel Drive       (FFS)        2200      Subaru
# 43661  4-Wheel or All-Wheel Drive       (FFS)        2200      Subaru
# 43662  4-Wheel or All-Wheel Drive  (FFS,TRBO)        3100      Subaru
#
#                      model            trany  range  \
# 0       Spider Veloce 2000     Manual 5-spd      0
# 1               Testarossa     Manual 5-spd      0
# 2                  Charger     Manual 5-spd      0
# 3      B150/B250 Wagon 2WD  Automatic 3-spd      0
# 4         Legacy AWD Turbo     Manual 5-spd      0
# ...                    ...              ...    ...
# 43658               Legacy  Automatic 4-spd      0
# 43659               Legacy     Manual 5-spd      0
# 43660           Legacy AWD  Automatic 4-spd      0
# 43661           Legacy AWD     Manual 5-spd      0
# 43662     Legacy AWD Turbo  Automatic 4-spd      0
#
#                           createdOn  year
# 0      Tue Jan 01 00:00:00 EST 2013  1985
# 1      Tue Jan 01 00:00:00 EST 2013  1985
# 2      Tue Jan 01 00:00:00 EST 2013  1985
# 3      Tue Jan 01 00:00:00 EST 2013  1985
# 4      Tue Jan 01 00:00:00 EST 2013  1993
# ...                             ...   ...
# 43658  Tue Jan 01 00:00:00 EST 2013  1993
# 43659  Tue Jan 01 00:00:00 EST 2013  1993
# 43660  Tue Jan 01 00:00:00 EST 2013  1993
# 43661  Tue Jan 01 00:00:00 EST 2013  1993
# 43662  Tue Jan 01 00:00:00 EST 2013  1993
#
# [43663 rows x 14 columns]

# %%
autos2 = tweak_autos(autos)

# try to be more Euro-centric

def to_lper100km(val):
    return 235.215 / val
autos2.city08.apply(to_lper100km)
# Out:
#        city08  comb08  highway08  cylinders     displ  \
# 0          19      21         25          4  2.000000
# 1           9      11         14         12  4.898438
# 2          23      27         33          4  2.199219
# 3          10      11         12          8  5.199219
# 4          17      19         23          4  2.199219
# ...       ...     ...        ...        ...       ...
# 43658      19      22         26          4  2.199219
# 43659      20      23         28          4  2.199219
# 43660      18      21         24          4  2.199219
# 43661      18      21         24          4  2.199219
# 43662      16      18         21          4  2.199219
#
#                             drive    eng_dscr  fuelCost08        make  \
# 0                Rear-Wheel Drive       (FFS)        2200  Alfa Romeo
# 1                Rear-Wheel Drive   (GUZZLER)        4200     Ferrari
# 2               Front-Wheel Drive       (FFS)        1700       Dodge
# 3                Rear-Wheel Drive         NaN        4200       Dodge
# 4      4-Wheel or All-Wheel Drive  (FFS,TRBO)        2950      Subaru
# ...                           ...         ...         ...         ...
# 43658           Front-Wheel Drive       (FFS)        2100      Subaru
# 43659           Front-Wheel Drive       (FFS)        2000      Subaru
# 43660  4-Wheel or All-Wheel Drive       (FFS)        2200      Subaru
# 43661  4-Wheel or All-Wheel Drive       (FFS)        2200      Subaru
# 43662  4-Wheel or All-Wheel Drive  (FFS,TRBO)        3100      Subaru
#
#                      model            trany  range                  createdOn  \
# 0       Spider Veloce 2000     Manual 5-spd      0  2013-01-01 00:00:00-05:00
# 1               Testarossa     Manual 5-spd      0  2013-01-01 00:00:00-05:00
# 2                  Charger     Manual 5-spd      0  2013-01-01 00:00:00-05:00
# 3      B150/B250 Wagon 2WD  Automatic 3-spd      0  2013-01-01 00:00:00-05:00
# 4         Legacy AWD Turbo     Manual 5-spd      0  2013-01-01 00:00:00-05:00
# ...                    ...              ...    ...                        ...
# 43658               Legacy  Automatic 4-spd      0  2013-01-01 00:00:00-05:00
# 43659               Legacy     Manual 5-spd      0  2013-01-01 00:00:00-05:00
# 43660           Legacy AWD  Automatic 4-spd      0  2013-01-01 00:00:00-05:00
# 43661           Legacy AWD     Manual 5-spd      0  2013-01-01 00:00:00-05:00
# 43662     Legacy AWD Turbo  Automatic 4-spd      0  2013-01-01 00:00:00-05:00
#
#        year automatic  speeds    ffs
# 0      1985     False       5   True
# 1      1985     False       5  False
# 2      1985     False       5   True
# 3      1985      True       3    NaN
# 4      1993     False       5   True
# ...     ...       ...     ...    ...
# 43658  1993      True       4   True
# 43659  1993     False       5   True
# 43660  1993      True       4   True
# 43661  1993     False       5   True
# 43662  1993      True       4   True
#
# [43663 rows x 17 columns]
# 0        12.379737
# 1        26.135000
# 2        10.226739
# 3        23.521500
# 4        13.836176
#            ...
# 43658    12.379737
# 43659    11.760750
# 43660    13.067500
# 43661    13.067500
# 43662    14.700938
# Name: city08, Length: 43663, dtype: float64

# %%
# this gives the same results

235.215 / autos2.city08
# Out:
# 0        12.379737
# 1        26.135000
# 2        10.226739
# 3        23.521500
# 4        13.836176
#            ...
# 43658    12.379737
# 43659    11.760750
# 43660    13.067500
# 43661    13.067500
# 43662    14.700938
# Name: city08, Length: 43663, dtype: float64

# %%
# %%timeit
autos2.city08.apply(to_lper100km)
# Out:
# 7.48 ms ± 347 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %%timeit
235.215 / autos2.city08
# Out:
# 119 µs ± 1.62 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
# ~50x slower!
6_220 / 125
# Out:
# 49.76

# %%
def is_american(val):
    return val in {'Chevrolet', 'Ford', 'Dodge', 'GMC', 'Tesla'}

# %%
# %%timeit
autos2.make.apply(is_american)
# Out:
# 1.04 ms ± 49.1 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %%timeit
autos2.make.isin({'Chevrolet', 'Ford', 'Dodge', 'GMC', 'Tesla'})
# Out:
# 744 µs ± 34.8 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %%timeit
# converted to string
autos2.make.astype(str).isin({'Chevrolet', 'Ford', 'Dodge', 'GMC', 'Tesla'})
# Out:
# 10.6 ms ± 136 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %%timeit
# converted to string
autos2.make.astype(str).apply(is_american)
# Out:
# 18.5 ms ± 2.02 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
def country(val):
    if val in {'Chevrolet', 'Ford', 'Dodge', 'GMC', 'Tesla'}:
        return 'US'
    return 'Other'

# %%
# %%timeit
# Might be ok for strings, since they are not vectorized...
(autos2
 .assign(country=autos2.make.apply(country))
)
# Out:
# 5.61 ms ± 253 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %%timeit
values = {'Chevrolet', 'Ford', 'Dodge', 'GMC', 'Tesla'}
(autos
 .assign(country='US')
 .assign(country=lambda df_:df_.country.where(df_.make.isin(values), 'Other'))
)
# Out:
# 43.4 ms ± 1.31 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %%timeit
(autos2
 .assign(country=np.select([autos2.make.isin({'Chevrolet', 'Ford', 'Dodge', 'GMC', 'Tesla'})],
                                            ['US'], 'Other'))
)
# Out:
# 9.7 ms ± 262 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %%timeit

(autos2
 .assign(country=np.where(autos2.make.isin({'Chevrolet', 'Ford', 'Dodge', 'GMC', 'Tesla'}),
                         'US', 'Other'))
)
# Out:
# 9.71 ms ± 196 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# Master Aggregation

(autos2
 .groupby('year')
 .mean()
)
# Out:
#          city08     comb08  highway08  cylinders     displ   fuelCost08  \
# year
# 1984  17.982688  19.881874  23.075356   5.385438  3.164062  2513.085540
# 1985  17.878307  19.808348  23.042328   5.375661  3.164062  2538.624339
# 1986  17.665289  19.550413  22.699174   5.425620  3.183594  2563.057851
# 1987  17.310345  19.228549  22.445068   5.412189  3.173828  2617.923015
# 1988  17.333628  19.328319  22.702655   5.461947  3.195312  2599.778761
# 1989  17.143972  19.125759  22.465742   5.488291  3.208984  2649.609714
# 1990  17.033395  19.000928  22.337662   5.496289  3.216797  2653.153989
# 1991  16.848940  18.825972  22.253534   5.598940  3.267578  2710.026502
# 1992  16.805531  18.862623  22.439786   5.623550  3.275391  2715.343443
# 1993  16.998170  19.104300  22.780421   5.602928  3.248047  2671.088747
# 1994  16.918534  19.012220  22.725051   5.704684  3.333984  2675.763747
# 1995  16.569804  18.797311  22.671148   5.892451  3.472656  2716.907963
# 1996  17.289780  19.584735  23.569211   5.627426  3.234375  2587.580854
# 1997  17.135171  19.429134  23.451444   5.666667  3.226562  2619.881890
# 1998  17.113300  19.518473  23.546798   5.633005  3.201172  2594.211823
# 1999  17.272300  19.611502  23.552817   5.667840  3.189453  2603.814554
# 2000  17.221429  19.526190  23.414286   5.713095  3.201172  2643.928571
# 2001  17.275521  19.479693  23.328211   5.720088  3.193359  2661.416026
# 2002  16.893333  19.168205  23.030769   5.827692  3.263672  2697.743590
# 2003  16.780651  19.000958  22.836207   5.942529  3.357422  2748.275862
# 2004  16.740642  19.067736  23.064171   5.957219  3.394531  2731.729055
# 2005  16.851630  19.193825  23.297599   5.944254  3.400391  2737.735849
# 2006  16.626812  18.959239  23.048913   6.100543  3.548828  2761.458333
# 2007  16.605684  18.978686  23.083481   6.166075  3.628906  2756.616341
# 2008  16.900590  19.276327  23.455771   6.192923  3.638672  2755.897220
# 2009  17.333616  19.735817  24.018628   6.122777  3.626953  2639.627434
# 2010  18.106691  20.590416  24.950271   5.965642  3.503906  2556.374322
# 2011  18.668739  21.009769  25.168739   5.980462  3.523438  2539.342806
# 2012  19.362685  21.818657  26.102005   5.910201  3.462891  2491.630340
# 2013  20.656780  23.121186  27.496610   5.761864  3.328125  2406.271186
# 2014  21.019656  23.515152  27.960688   5.747748  3.292969  2391.728092
# 2015  21.433594  24.024219  28.572656   5.637500  3.207031  2337.265625
# 2016  22.565769  25.118859  29.576862   5.471474  3.058594  2277.496038
# 2017  22.760247  25.247486  29.552978   5.450116  3.025391  2279.698376
# 2018  22.544510  25.000742  29.253709   5.443620  2.994141  2289.762611
# 2019  23.347988  25.648286  29.662444   5.368107  2.962891  2283.867362
# 2020  23.699920  25.907422  29.490024   5.438947  3.000000  2309.896249
# 2021  23.907258  25.945161  29.266129   5.419355  3.035156  2321.774194
# 2022  24.793103  26.952586  30.681034   4.693966  2.519531  2064.655172
#
#          range    speeds
# year
# 1984  0.000000  3.928208
# 1985  0.000000  3.924750
# 1986  0.000000  3.984298
# 1987  0.000000  4.037690
# 1988  0.000000  4.129204
# 1989  0.000000  4.166522
# 1990  0.000000  4.238404
# 1991  0.000000  4.301237
# 1992  0.000000  4.318466
# 1993  0.000000  4.339433
# 1994  0.000000  4.332994
# 1995  0.000000  4.356774
# 1996  0.000000  4.364812
# 1997  0.000000  4.402887
# 1998  0.229064  4.419951
# 1999  0.570423  4.421362
# 2000  0.348810  4.508333
# 2001  0.261251  4.660812
# 2002  0.136410  4.757949
# 2003  0.090996  4.911877
# 2004  0.000000  4.976827
# 2005  0.000000  5.192110
# 2006  0.000000  5.315217
# 2007  0.000000  5.610124
# 2008  0.084246  5.773378
# 2009  0.000000  6.040644
# 2010  0.000000  6.269439
# 2011  0.260213  6.558615
# 2012  0.785527  6.705318
# 2013  1.259322  6.896610
# 2014  1.410319  6.985258
# 2015  2.213281  7.035938
# 2016  4.546751  7.080032
# 2017  4.336427  7.225058
# 2018  3.508902  7.017062
# 2019  5.978390  7.116990
# 2020  7.895451  7.278532
# 2021  8.658065  6.810484
# 2022  2.672414  7.922414

# %%
# watch order of column filtering/aggregation
(autos2
 .groupby('year')
 [['comb08', 'speeds']]
 .mean()
)
# Out:
#          comb08    speeds
# year
# 1984  19.881874  3.928208
# 1985  19.808348  3.924750
# 1986  19.550413  3.984298
# 1987  19.228549  4.037690
# 1988  19.328319  4.129204
# 1989  19.125759  4.166522
# 1990  19.000928  4.238404
# 1991  18.825972  4.301237
# 1992  18.862623  4.318466
# 1993  19.104300  4.339433
# 1994  19.012220  4.332994
# 1995  18.797311  4.356774
# 1996  19.584735  4.364812
# 1997  19.429134  4.402887
# 1998  19.518473  4.419951
# 1999  19.611502  4.421362
# 2000  19.526190  4.508333
# 2001  19.479693  4.660812
# 2002  19.168205  4.757949
# 2003  19.000958  4.911877
# 2004  19.067736  4.976827
# 2005  19.193825  5.192110
# 2006  18.959239  5.315217
# 2007  18.978686  5.610124
# 2008  19.276327  5.773378
# 2009  19.735817  6.040644
# 2010  20.590416  6.269439
# 2011  21.009769  6.558615
# 2012  21.818657  6.705318
# 2013  23.121186  6.896610
# 2014  23.515152  6.985258
# 2015  24.024219  7.035938
# 2016  25.118859  7.080032
# 2017  25.247486  7.225058
# 2018  25.000742  7.017062
# 2019  25.648286  7.116990
# 2020  25.907422  7.278532
# 2021  25.945161  6.810484
# 2022  26.952586  7.922414

# %%
# %%timeit
(autos2
 .groupby('year')
 #.mean()
 [['comb08', 'speeds']]
 .mean()
)
# Out:
# 2.12 ms ± 166 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
#plt.style.use('pandas1book')
sns.set_context('talk')
plt.plot(range(10))

# %%
(autos2
 .groupby('year')
 [['comb08', 'speeds']]
 .mean()
 .plot()
)
# Out:
# <AxesSubplot:xlabel='year'>

# %%
(autos2
 .groupby('year')
 [['comb08', 'speeds']]
 #.median()
 .quantile(.1)
 .plot()
)
# Out:
# <AxesSubplot:xlabel='year'>

# %%
(autos2
 .assign(country=autos2.make.apply(country))
 .groupby(['year', 'country'])
 .mean()
)
# Out:
#                  city08     comb08  highway08  cylinders     displ  \
# year country
# 1984 Other    19.384615  21.417330  24.847038   4.908046  2.691406
#      US       16.079232  17.797119  20.669868   6.033613  3.808594
# 1985 Other    19.284768  21.373068  24.816777   4.871965  2.636719
#      US       16.275472  18.025157  21.020126   5.949686  3.765625
# 1986 Other    19.167183  21.213622  24.650155   4.804954  2.537109
# ...                 ...        ...        ...        ...       ...
# 2020 US       27.324111  28.992095  31.114625   5.498024  3.478516
# 2021 Other    23.717277  25.896335  29.612565   5.318325  2.841797
#      US       24.543860  26.108772  28.105263   5.757895  3.685547
# 2022 Other    24.284946  26.532258  30.387097   4.827957  2.595703
#      US       26.847826  28.652174  31.869565   4.152174  2.208984
#
#                fuelCost08      range    speeds
# year country
# 1984 Other    2299.160035   0.000000  3.969054
#      US       2803.541417   0.000000  3.872749
# 1985 Other    2327.483444   0.000000  3.958057
#      US       2779.245283   0.000000  3.886792
# 1986 Other    2339.705882   0.000000  4.069659
# ...                   ...        ...       ...
# 2020 US       2256.126482  26.648221  5.375494
# 2021 Other    2305.549738   5.100524  7.539267
#      US       2376.140351  20.578947  4.368421
# 2022 Other    2108.602151   0.612903  7.591398
#      US       1886.956522  11.000000  9.260870
#
# [78 rows x 8 columns]

# %%
# can go deeper and apply multiple aggregates

def second_to_last(ser):
    return ser.iloc[-2]
(autos2
 .assign(country=autos2.make.apply(country))
 .groupby(['year', 'country'])
 .agg(['min', 'mean', second_to_last])
)
# Out:
# /var/folders/f1/wtwxfqyx21l43chdpfznnk9h0000gn/T/ipykernel_2446/305248578.py:5: FutureWarning: ['drive', 'make', 'model', 'createdOn'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   (autos2
#              city08                           comb08             \
#                 min       mean second_to_last    min       mean
# year country
# 1984 Other        7  19.384615             14      8  21.417330
#      US           8  16.079232             15      9  17.797119
# 1985 Other        7  19.284768             19      8  21.373068
#      US           8  16.275472             14     10  18.025157
# 1986 Other        6  19.167183             10      7  21.213622
# ...             ...        ...            ...    ...        ...
# 2020 US          12  27.324111            127     14  28.992095
# 2021 Other        8  23.717277             13     10  25.896335
#      US          12  24.543860            124     13  26.108772
# 2022 Other       13  24.284946             13     15  26.532258
#      US          16  26.847826             19     17  28.652174
#
#                             highway08                           cylinders  \
#              second_to_last       min       mean second_to_last       min
# year country
# 1984 Other               14         9  24.847038             15         2
#      US                  17        10  20.669868             19         4
# 1985 Other               20         9  24.816777             22         0
#      US                  15        10  21.020126             17         3
# 1986 Other               11         9  24.650155             12         0
# ...                     ...       ...        ...            ...       ...
# 2020 US                 121      -124  31.114625            114         0
# 2021 Other               16        13  29.612565             19         0
#      US                 120      -123  28.105263            115         0
# 2022 Other               15        18  30.387097             19         0
#      US                  21        18  31.869565             26         0
#
#               ...          range automatic                          speeds  \
#               ... second_to_last       min      mean second_to_last    min
# year country  ...
# 1984 Other    ...              0     False  0.550840          False      3
#      US       ...              0     False  0.521059          False      3
# 1985 Other    ...              0     False  0.554084           True      3
#      US       ...              0     False  0.520755          False      3
# 1986 Other    ...              0     False  0.520124          False      3
# ...           ...            ...       ...       ...            ...    ...
# 2020 US       ...            316     False  0.928854           True      0
# 2021 Other    ...              0     False  0.928796           True      0
#      US       ...            405     False  0.929825           True      0
# 2022 Other    ...              0     False  0.919355           True      0
#      US       ...              0     False  0.956522           True      5
#
#                                          ffs
#                   mean second_to_last    min      mean second_to_last
# year country
# 1984 Other    3.969054              5  False  0.714554           True
#      US       3.872749              4  False  0.638801            NaN
# 1985 Other    3.958057              4  False  0.889160           True
#      US       3.886792              4  False  0.851351            NaN
# 1986 Other    4.069659              4  False  0.934211            NaN
# ...                ...            ...    ...       ...            ...
# 2020 US       5.375494              1  False  0.000000            NaN
# 2021 Other    7.539267              0  False  0.000000          False
#      US       4.368421              1  False  0.000000            NaN
# 2022 Other    7.591398              8  False  0.000000            NaN
#      US       9.260870              9  False  0.000000          False
#
# [78 rows x 30 columns]

# %%
# back to simpler example, adding plots
(autos2
 .assign(country=autos2.make.apply(country))
 .groupby(['year', 'country'])
 .mean()
 .plot()
)
# Out:
# <AxesSubplot:xlabel='year,country'>

# %%
(autos2
 .assign(country=autos2.make.apply(country))
 .groupby(['year', 'country'])
 .mean()
 .unstack()
)
# Out:
#             city08                comb08             highway08             \
# country      Other         US      Other         US      Other         US
# year
# 1984     19.384615  16.079232  21.417330  17.797119  24.847038  20.669868
# 1985     19.284768  16.275472  21.373068  18.025157  24.816777  21.020126
# 1986     19.167183  15.945035  21.213622  17.645390  24.650155  20.464539
# 1987     18.633381  15.611722  20.710414  17.326007  24.186876  20.208791
# 1988     18.668224  15.577869  20.814642  17.372951  24.437695  20.420082
# 1989     18.533040  15.139831  20.662261  16.908898  24.252570  19.887712
# 1990     18.510109  14.850575  20.640747  16.577011  24.267496  19.485057
# 1991     18.087943  14.803279  20.174468  16.599532  23.809929  19.683841
# 1992     17.915374  14.895631  20.098731  16.735437  23.820874  20.063107
# 1993     18.084866  15.007772  20.309760  16.896373  24.172560  20.230570
# 1994     18.046474  14.952514  20.264423  16.829609  24.173077  20.201117
# 1995     17.678914  14.533724  20.091054  16.422287  24.263578  19.747801
# 1996     18.480545  14.926641  20.906615  16.961390  25.093385  20.544402
# 1997     18.090909  14.978632  20.509470  16.991453  24.678030  20.683761
# 1998     17.925267  15.288000  20.457295  17.408000  24.704626  20.944000
# 1999     17.925125  15.709163  20.386023  17.756972  24.577371  21.099602
# 2000     17.881849  15.714844  20.301370  17.757812  24.416096  21.128906
# 2001     17.941267  15.643939  20.289026  17.496212  24.372488  20.768939
# 2002     17.644412  15.083916  20.076923  16.979021  24.207547  20.195804
# 2003     17.565101  14.826087  19.953020  16.628763  24.052349  19.806020
# 2004     17.426290  14.928571  19.923833  16.805195  24.160934  20.165584
# 2005     17.412170  15.196610  19.892078  17.132203  24.189437  20.664407
# 2006     17.062575  15.300366  19.509025  17.285714  23.762936  20.875458
# 2007     16.996403  15.489726  19.452038  17.626712  23.742206  21.202055
# 2008     17.239869  15.770073  19.677985  17.937956  23.983571  21.697080
# 2009     17.696903  16.148014  20.188053  18.259928  24.594027  22.140794
# 2010     18.327606  17.278970  20.854525  19.600858  25.261168  23.785408
# 2011     19.249708  16.817844  21.635939  19.014870  25.857643  22.973978
# 2012     19.840547  17.802974  22.341686  20.111524  26.694761  24.167286
# 2013     20.978518  19.453815  23.468314  21.823293  27.852846  26.164659
# 2014     21.143293  20.506329  23.636179  23.012658  28.066057  27.523207
# 2015     21.334317  21.817490  23.916421  24.441065  28.463127  28.996198
# 2016     21.870314  25.061818  24.399189  27.701818  28.827761  32.265455
# 2017     22.422812  24.003623  24.908555  26.496377  29.206490  30.829710
# 2018     22.285848  23.526690  24.757263  25.925267  29.018744  30.145907
# 2019     22.916588  24.933798  25.290047  26.965157  29.383886  30.686411
# 2020     22.783000  27.324111  25.127000  28.992095  29.079000  31.114625
# 2021     23.717277  24.543860  25.896335  26.108772  29.612565  28.105263
# 2022     24.284946  26.847826  26.532258  28.652174  30.387097  31.869565
#
#         cylinders               displ             fuelCost08               \
# country     Other        US     Other        US        Other           US
# year
# 1984     4.908046  6.033613  2.691406  3.808594  2299.160035  2803.541417
# 1985     4.871965  5.949686  2.636719  3.765625  2327.483444  2779.245283
# 1986     4.804954  6.136525  2.537109  3.925781  2339.705882  2818.882979
# 1987     4.825963  6.164835  2.583984  3.931641  2425.249643  2865.293040
# 1988     4.819315  6.307377  2.531250  4.066406  2404.127726  2857.172131
# 1989     4.879589  6.366525  2.542969  4.171875  2449.412628  2938.453390
# 1990     4.839813  6.466667  2.507812  4.265625  2436.314152  2973.678161
# 1991     5.029787  6.538642  2.609375  4.351562  2554.042553  2967.564403
# 1992     5.145275  6.446602  2.708984  4.250000  2581.170663  2946.237864
# 1993     5.114569  6.497409  2.683594  4.281250  2537.270156  2916.191710
# 1994     5.185897  6.608939  2.712891  4.414062  2528.445513  2932.541899
# 1995     5.444089  6.715543  2.908203  4.507812  2561.421725  3002.346041
# 1996     5.147860  6.579151  2.708984  4.277344  2450.486381  2859.652510
# 1997     5.261364  6.581197  2.787109  4.218750  2524.810606  2834.401709
# 1998     5.275801  6.436000  2.800781  4.105469  2497.686833  2811.200000
# 1999     5.377704  6.362550  2.832031  4.042969  2515.640599  2814.940239
# 2000     5.441781  6.332031  2.859375  3.978516  2593.065068  2759.960938
# 2001     5.479134  6.310606  2.873047  3.976562  2605.023184  2799.621212
# 2002     5.576197  6.433566  2.935547  4.058594  2634.397678  2850.349650
# 2003     5.683221  6.588629  3.031250  4.171875  2694.899329  2881.270903
# 2004     5.729730  6.558442  3.087891  4.199219  2689.987715  2842.045455
# 2005     5.773823  6.447458  3.152344  4.132812  2707.979334  2825.593220
# 2006     5.977136  6.476190  3.345703  4.171875  2745.848375  2808.974359
# 2007     6.044365  6.513699  3.423828  4.210938  2762.829736  2738.869863
# 2008     6.095290  6.518248  3.462891  4.222656  2768.729463  2713.138686
# 2009     5.970133  6.620939  3.404297  4.351562  2643.418142  2627.256318
# 2010     5.896907  6.223176  3.359375  4.050781  2579.438717  2469.957082
# 2011     5.850642  6.394052  3.320312  4.167969  2527.771295  2576.208178
# 2012     5.791572  6.297398  3.269531  4.085938  2480.239180  2528.810409
# 2013     5.657358  6.152610  3.179688  3.884766  2401.450054  2424.297189
# 2014     5.722561  5.852321  3.214844  3.615234  2405.589431  2334.177215
# 2015     5.607670  5.752852  3.103516  3.605469  2353.294002  2275.285171
# 2016     5.503546  5.356364  2.996094  3.277344  2318.186424  2131.454545
# 2017     5.427729  5.532609  2.919922  3.419922  2299.065880  2208.333333
# 2018     5.402999  5.597865  2.890625  3.390625  2309.840675  2213.523132
# 2019     5.331754  5.501742  2.849609  3.382812  2291.184834  2256.968641
# 2020     5.424000  5.498024  2.878906  3.478516  2323.500000  2256.126482
# 2021     5.318325  5.757895  2.841797  3.685547  2305.549738  2376.140351
# 2022     4.827957  4.152174  2.595703  2.208984  2108.602151  1886.956522
#
#             range               speeds
# country     Other         US     Other        US
# year
# 1984     0.000000   0.000000  3.969054  3.872749
# 1985     0.000000   0.000000  3.958057  3.886792
# 1986     0.000000   0.000000  4.069659  3.886525
# 1987     0.000000   0.000000  4.142653  3.902930
# 1988     0.000000   0.000000  4.205607  4.028689
# 1989     0.000000   0.000000  4.264317  4.025424
# 1990     0.000000   0.000000  4.328149  4.105747
# 1991     0.000000   0.000000  4.341844  4.234192
# 1992     0.000000   0.000000  4.356841  4.252427
# 1993     0.000000   0.000000  4.371994  4.279793
# 1994     0.000000   0.000000  4.355769  4.293296
# 1995     0.000000   0.000000  4.380192  4.313783
# 1996     0.000000   0.000000  4.416342  4.262548
# 1997     0.000000   0.000000  4.452652  4.290598
# 1998     0.144128   0.420000  4.485765  4.272000
# 1999     0.251248   1.334661  4.507488  4.215139
# 2000     0.304795   0.449219  4.619863  4.253906
# 2001     0.187017   0.443182  4.761978  4.412879
# 2002     0.137881   0.132867  4.920174  4.367133
# 2003     0.127517   0.000000  5.154362  4.307692
# 2004     0.000000   0.000000  5.229730  4.308442
# 2005     0.000000   0.000000  5.362801  4.688136
# 2006     0.000000   0.000000  5.492178  4.776557
# 2007     0.000000   0.000000  5.864508  4.883562
# 2008     0.109529   0.000000  5.969332  5.120438
# 2009     0.000000   0.000000  6.186947  5.563177
# 2010     0.000000   0.000000  6.376861  5.866953
# 2011     0.341890   0.000000  6.712952  6.066914
# 2012     0.637813   1.267658  6.833713  6.286245
# 2013     0.857143   2.763052  7.033298  6.385542
# 2014     0.862805   3.683544  7.211382  6.046414
# 2015     0.640118   8.296578  7.212389  6.353612
# 2016     1.017224  17.214545  7.296859  6.301818
# 2017     1.243854  15.731884  7.474926  6.304348
# 2018     1.131209  12.537367  7.389878  5.601423
# 2019     2.350711  19.313589  7.529858  5.599303
# 2020     3.151000  26.648221  7.760000  5.375494
# 2021     5.100524  20.578947  7.539267  4.368421
# 2022     0.612903  11.000000  7.591398  9.260870

# %%
(autos2
 .assign(country=autos2.make.apply(country))
 .groupby(['year', 'country'])
 .mean()
 .unstack()
 .city08
 .plot()
 .legend(bbox_to_anchor=(1,1))
)

# %%
(autos2
 .assign(country=autos2.make.apply(country))
 .groupby(['year', 'country'])
 .mean()
 .unstack() # change row to column
 .city08
 .rolling(2)
 .mean()
 .plot()
 .legend(bbox_to_anchor=(1,1))
)

# %%
def vals_gt(df_, num):
    return df_[df_.gt(num)].dropna()
(autos2
 .assign(country=autos2.make.apply(country))
 .groupby(['year', 'country'])
 .count()
 .pipe(vals_gt, 700)
)
# Out:
#               city08  comb08  highway08  cylinders   displ   drive  \
# year country
# 1984 Other    1131.0  1131.0     1131.0     1131.0  1131.0  1131.0
# 1985 Other     906.0   906.0      906.0      906.0   906.0   906.0
# 1991 Other     705.0   705.0      705.0      705.0   705.0   705.0
# 1992 Other     709.0   709.0      709.0      709.0   709.0   709.0
# 1993 Other     707.0   707.0      707.0      707.0   707.0   707.0
# 2017 Other    1017.0  1017.0     1017.0     1017.0  1017.0  1017.0
# 2018 Other    1067.0  1067.0     1067.0     1067.0  1067.0  1067.0
# 2019 Other    1055.0  1055.0     1055.0     1055.0  1055.0  1055.0
# 2020 Other    1000.0  1000.0     1000.0     1000.0  1000.0  1000.0
# 2021 Other     955.0   955.0      955.0      955.0   955.0   955.0
#
#               fuelCost08    make   model   range  createdOn  automatic  \
# year country
# 1984 Other        1131.0  1131.0  1131.0  1131.0     1131.0     1131.0
# 1985 Other         906.0   906.0   906.0   906.0      906.0      906.0
# 1991 Other         705.0   705.0   705.0   705.0      705.0      705.0
# 1992 Other         709.0   709.0   709.0   709.0      709.0      709.0
# 1993 Other         707.0   707.0   707.0   707.0      707.0      707.0
# 2017 Other        1017.0  1017.0  1017.0  1017.0     1017.0     1017.0
# 2018 Other        1067.0  1067.0  1067.0  1067.0     1067.0     1067.0
# 2019 Other        1055.0  1055.0  1055.0  1055.0     1055.0     1055.0
# 2020 Other        1000.0  1000.0  1000.0  1000.0     1000.0     1000.0
# 2021 Other         955.0   955.0   955.0   955.0      955.0      955.0
#
#               speeds     ffs
# year country
# 1984 Other    1131.0  1065.0
# 1985 Other     906.0   821.0
# 1991 Other     705.0   705.0
# 1992 Other     709.0   707.0
# 1993 Other     707.0   707.0
# 2017 Other    1017.0   766.0
# 2018 Other    1067.0   844.0
# 2019 Other    1055.0   879.0
# 2020 Other    1000.0   842.0
# 2021 Other     955.0   814.0
